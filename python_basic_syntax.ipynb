# %% [markdown]
# # Basic Syntax

# %% [markdown]
# ### 1. Python Opearators

# %% [markdown]
# #### Basic Arithmatic Opeartions

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=10
b=3

print("a+b :",a+b)
print("a-b :",a-b)
print("a*b :",a*b)
print("a/b :",a/b)
print("a//b :",a//b)
print("a%b :",a%b)
print("a**b :",a**b)
# Out:
# a+b : 13
# a-b : 7
# a*b : 30
# a/b : 3.3333333333333335
# a//b : 3
# a%b : 1
# a**b : 1000

# %% [markdown]
# #### Basic Assignment Opeartions

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
num = 100 
num += 50 # equivalant to num = num + 50
print(num)
# Out:
# 150

# %%
a = 100
a -= 1
a
# Out:
# 99

# %% [markdown]
# #### Python Comparison Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Python Logical Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Python Identity Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Python Membership Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Pytho Bitwise Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###  2. Control & Conditional Structure
