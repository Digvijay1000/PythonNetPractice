# %% [markdown]
# # Day9 - Dictionaries, Nesting and the Secret Auction

# %% [markdown]
# ### Dictionary
#
# Key - Value Pair
#
# e.g : Bug - An error in a program that prevents the program from running as expected
#
# Bug is key and value are messages

# %%
programming_dictionary = {"Bug" : "An error in a program that prevents the program from running as expected",
                          "Function" : "A piece of code that you can easily call over and over again"
                          }

# %%
programming_dictionary
# Out:
# {'Bug': 'An error in a program that prevents the program from running as expected',
#  'Function': 'A piece of code that you can easily call over and over again'}

# %%
type(programming_dictionary)
# Out:
# dict

# %%
# Retrive item from dictionary
programming_dictionary["Bug"]
# Out:
# 'An error in a program that prevents the program from running as expected'

# %%
programming_dictionary.keys()
# Out:
# dict_keys(['Bug', 'Function'])

# %%
programming_dictionary["Loop"] = "The action of doing something that over and over again"

# %%
print(programming_dictionary)
# Out:
# {'Bug': 'An error in a program that prevents the program from running as expected', 'Function': 'A piece of code that you can easily call over and over again', 'Loop': 'The action of doing something that over and over again'}

# %%
# empty dictionary

empty_dictionary = {} # by using {} we can create empty dictionary

# %%
print(empty_dictionary)
# Out:
# {}

# %%
# wipe an existing dictionary
# programming_dictionary = {}
# print(programming_dictionary)

# %%
# Edit an item in dictionary

programming_dictionary['Bug'] = 'An moth in your computer'
programming_dictionary
# Out:
# {'Bug': 'An moth in your computer',
#  'Function': 'A piece of code that you can easily call over and over again',
#  'Loop': 'The action of doing something that over and over again'}

# %%
# Loop through dictionary

for key in programming_dictionary:
    print(key)
# Out:
# Bug
# Function
# Loop

# %%
for key in programming_dictionary:
    print(programming_dictionary[key])
# Out:
# An moth in your computer
# A piece of code that you can easily call over and over again
# The action of doing something that over and over again

# %% [markdown]
# #### Grading Program
#
# You have access to a database of student_scores in the format of a dictionary. The keys in student_scores are the names of the students and the values are their exam scores.
#
# Write a program that converts their scores to grades.
#
# By the end of your program, you should have a new dictionary called student_grades that should contain student names as keys and their assessed grades for values.
#
# The final version of the student_grades dictionary will be checked.
#
# student_scores = {
#     'Harry': 88,
#     'Ron': 78,
#     'Hermione': 95,
#     'Draco': 75,
#     'Neville': 60
# }
#
# This is the scoring criteria:
#
# - Scores 91 - 100: Grade = "Outstanding"
#
# - Scores 81 - 90: Grade = "Exceeds Expectations"
#
# - Scores 71 - 80: Grade = "Acceptable"
#
# - Scores 70 or lower: Grade = "Fail"

# %%
student_scores = {
    'Harry': 88,
    'Ron': 78,
    'Hermione': 95,
    'Draco': 75,
    'Neville': 60,
    'Mandy' : 40
}


print(student_scores)


student_grades = {}

for key in student_scores: 
    if student_scores[key] > 70 and student_scores[key] <= 80:
        student_grades[key] = "Acceptable"
    elif student_scores[key] > 80 and student_scores[key] <= 90:
        student_grades[key] = "Exceeds Expectations"
    elif student_scores[key] > 90 and student_scores[key] <= 100:
        student_grades[key] = "Outstanding"
    else:
        student_grades[key] = "Fail"

print(student_grades)
# Out:
# {'Harry': 88, 'Ron': 78, 'Hermione': 95, 'Draco': 75, 'Neville': 60, 'Mandy': 40}
# {'Harry': 'Exceeds Expectations', 'Ron': 'Acceptable', 'Hermione': 'Outstanding', 'Draco': 'Acceptable', 'Neville': 'Fail', 'Mandy': 'Fail'}

# %%
# creating dictionary by using list
l1 = ['A', 'B', 'C']
l2 = [10, 20, 30]

print(l1, type(l1), l2, type(l2))

d = dict(zip(l1,l2))

print(d,type(d))
# Out:
# ['A', 'B', 'C'] <class 'list'> [10, 20, 30] <class 'list'>
# {'A': 10, 'B': 20, 'C': 30} <class 'dict'>

# %%
# creating dictionary by using tuple
t1 = ('X', 'Y', 'Z')
t2 = (100, 200, 300)

dt = dict(zip(t1, t2))

print(dt, type(dt))
# Out:
# {'X': 100, 'Y': 200, 'Z': 300} <class 'dict'>

# %% [markdown]
# ### Nesting Lists and Dictionaries

# %% [markdown]
# {
#
#     key : [list],
#     key2 : {dict},
# }

# %%
capitals = {

    "France" : "Paris",
    "Germany" : "Berlin"
}

print(capitals)

# Nested list in dictionary

travel_log = {

    "France" : ["Paris", "Lille", "Dijon"],
    "Germany" : ["Stuttgart", "Berlin"]

}

print(travel_log["France"][1]) # accessing lilly
# Out:
# {'France': 'Paris', 'Germany': 'Berlin'}
# Lille

# %%
# Accessing nested list

nested_list = ["A", "B", ["C", "D"]]
print(nested_list[2][1])
# Out:
# D

# %%
# Accessing nested dictionary
travel_log = {

    "France" : {
        "cities_visited" : ["Paris", "Lille", "Dijon"],
        "total_visits" : 12,
    },

    "Germany" : {
        "num_times_visited" : 8,
        "cities_visited" : ["Berlin", "Hamburg", "Stuttgart"],
        "total_visits" : 5
    }

}

print(travel_log)
# Out:
# {'France': {'cities_visited': ['Paris', 'Lille', 'Dijon'], 'total_visits': 12}, 'Germany': {'num_times_visited': 8, 'cities_visited': ['Berlin', 'Hamburg', 'Stuttgart'], 'total_visits': 5}}

# %%
# accessing "Stuttgart"

print(travel_log["Germany"]["cities_visited"][2])
# Out:
# Stuttgart

# %% [markdown]
# #### Quiz

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Day9 - Project : The Secret Auction Program Instructions and Flow Chart

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# step-1: Ask user to input
# step-2: Save data into dictionary {name:price}
# step-3: Wheathher if new bids need to be added
# step -4: Compair bids in dictionary

def find_highest_bidder(bidding_dictionary):
    winner = ""
    highest_bid = 0

    max(bidding_dictionary)

    for bidder in bidding_dictionary:
        bid_amount = bidding_dictionary[bidder]
        if bid_amount > highest_bid:
            highest_bid = bid_amount
            winner = bidder

    print(f"Winner is {winner} with a bid of ${highest_bid}")


 
bids = {}
continue_bidding = True
while continue_bidding:
    name = input("What is your name?: ")
    price = int(input("What is your bid?: $"))
    bids[name] = price
    should_continue = input("Are there any other bidders? type 'yes' or 'no'.\n").lower()
    if should_continue == 'no':
        continue_bidding = False
        find_highest_bidder(bids)
    elif should_continue == 'yes':
        print("\n" * 20)
# Out:
# Winner is DIGVI with a bid of $200
