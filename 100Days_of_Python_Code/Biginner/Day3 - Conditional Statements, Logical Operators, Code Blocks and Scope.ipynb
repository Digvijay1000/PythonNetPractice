# %% [markdown]
# # Day3 - Conditional Statements, Logical Operators, Code Blocks and Scope

# %% [markdown]
# ### 1. Control Flow with if/else and Conditional operators

# %% [raw]
# if condition:
#     do this
# else:
#     do this

# %%
water_level = 50
if water_level > 80:
    print("Drain water")
else:
    print("Continue")
# Out:
# Continue

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Welcome to the rollercoaster!")
height = int(input("What is your height in cm? "))

if height > 120: # 120 not included if you want >=
    print("You can ride the rollercoaster!")
else:
    print("Sorry, you have to grow taller before you can ride.")
# Out:
# Welcome to the rollercoaster!
# What is your height in cm? 100
# Sorry, you have to grow taller before you can ride.

# %%
print("Welcome to the rollercoaster!")
height = int(input("What is your height in cm? "))

if height >= 120: # 120 not included if you want >=
    print("You can ride the rollercoaster!")
else:
    print("Sorry, you have to grow taller before you can ride.")
# Out:
# Welcome to the rollercoaster!
# What is your height in cm? 120
# You can ride the rollercoaster!

# %%
# comparision opeartors

a = 10
b = 20

print(a == b)   # Equal to
print(a != b)   # Not equal to
print(a > b)    # Greater than
print(a < b)    # Smaller than
print(a >= b)   # Greater than and equal to
print(a <= b)   # Smaller than and qual to
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# ###### Interactive Coding Exercise] Odd or Even? Introducing the Modulo

# %% [markdown]
# Write a program that works out whether if a given number is an odd or even number.
#
# Even numbers can be divided by 2 with no remainder.
#
# e.g. 86 is even because 86 ÷ 2 = 43
#
# 43 does not have any decimal places. Therefore the division is clean.
#
# e.g. 59 is odd because 59 ÷ 2 = 29.5
#
# 29.5 is not a whole number, it has decimal places. Therefore there is a remainder of 0.5, so the division is not clean.
#
# The modulo is written as a percentage sign (%) in Python. It gives you the remainder after a division.
#
# e.g.
#
# 6 ÷ 2 = 3 with no remainder.
#
# therefore: 6 % 2 = 0
#
# 5 ÷ 2 = 2 x 2 + 1, remainder is 1.
#
# therefore: 5 % 2 = 1
#
# 14 ÷ 4 = 3 x 4 + 2, remainder is 2.
#
# therefore: 14 % 4 = 2

# %%
# Which number do you want to check?
number = int(input())
# 🚨 Don't change the code above 👆

# Write your code below this line 👇
if number % 2 == 0:
  print("This is an even number.")
else:
  print("This is an odd number.")
# Out:
# 11
# This is an odd number.

# %% [markdown]
# ### 2. Nested if statements and elif statements

# %% [markdown]
# ###### # Nested if / else statement

# %% [raw]
# # Nested if / else statement
#
# if condition:
#     if another condition:
#         do this
#     else:
#         do this
# else:
#     do this

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Welcome to the rollercoaster!")
height = int(input("What is your height in cm? "))

if height >= 120: # 120 not included if you want >=
    print("You can ride the rollercoaster!")
    age = int(input("what is your age? "))
    if age <= 18:
        print("Please pay $7.")
    else:
        print("Please pay $12.")
else:
    print("Sorry, you have to grow taller before you can ride.")
# Out:
# Welcome to the rollercoaster!
# What is your height in cm? 121
# You can ride the rollercoaster!
# what is your age? 35
# Please pay $12.

# %% [markdown]
# ###### if / elif / else

# %% [raw]
# # if / elif / else
#
# if condition1:
#     do A
# elif condition2:
#     do B
# else:
#     do this

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Welcome to the rollercoaster!")
height = int(input("What is your height in cm? "))

if height >= 120: # 120 not included if you want >=
    print("You can ride the rollercoaster!")
    age = int(input("what is your age? "))
    if age < 12:
        print("Please pay $5.")
    elif age <= 18: # we can add elif multiple times
        print("Please pay $7.")
    else:
        print("Please pay $12.")
else:
    print("Sorry, you have to grow taller before you can ride.")
# Out:
# Welcome to the rollercoaster!
# What is your height in cm? 121
# You can ride the rollercoaster!
# what is your age? 5
# Please pay $5.

# %% [markdown]
# ###### Interactive Coding Exercise - BMI 2.0

# %% [raw]
# Write a program that interprets the Body Mass Index (BMI) based on a user's weight and height.
#
# It should tell them the interpretation of their BMI based on the BMI value.
#
# Under 18.5 they are underweight
# Equal to or over 18.5 but below 25 they have a normal weight
# Equal to or over 25 but below 30 they are slightly overweight
# Equal to or over 30 but below 35 they are obese
# Equal to or over 35 they are clinically obese.
#
# BMI = weight(kg)/ Height**2 (M2)

# %%
height = float(input("Enter the height in meter : "))
weight = int(input("Enter the weight in kg : "))

bmi = weight / height**2
bmi = float(bmi)

if bmi < 18.5:
    print(f"Your BMI is {bmi}, you are Underweight.")
elif bmi < 25:
    print(f"Your BMI is {bmi}, you have a normal weight.")
elif bmi < 30:
    print(f"Your BMI is {bmi}, you are slightly overweight.")
elif bmi < 35:
    print(f"Your BMI is {bmi}, you are obese.")
else:
    print(f"Your BMI is {bmi}, you are clinically obese.")
# Out:
# Enter the height in meter : 1.73
# Enter the weight in kg : 90
# Your BMI is 30.071168431955627, you are obese.

# %% [markdown]
# ###### Interactive Coding Exercise - Leap Year

# %% [raw]
# Write a program that works out whether if a given year is a leap year. A normal year has 365 days, leap years have 366, with an extra day in February. The reason why we have leap years is really fascinating, this video does it more justice.
#
# This is how you work out whether if a particular year is a leap year.
#
# on every year that is divisible by 4 with no remainder
#
# except every year that is evenly divisible by 100 with no remainder
#
# unless the year is also divisible by 400 with no remainder
#
# If english is not your first language or if the above logic is confusing, try using this flow chart .
#
# e.g. The year 2000:
#
# 2000 ÷ 4 = 500 (Leap)
#
# 2000 ÷ 100 = 20 (Not Leap)
#
# 2000 ÷ 400 = 5 (Leap!)
#
# So the year 2000 is a leap year.
#
# But the year 2100 is not a leap year because:
#
# 2100 ÷ 4 = 525 (Leap)
#
# 2100 ÷ 100 = 21 (Not Leap)
#
# 2100 ÷ 400 = 5.25 (Not Leap)
#
# Warning your output should match the Example Output format exactly, including spelling an punctuation.

# %%
year = int(input())
# 🚨 Don't change the code above 👆

# Write your code below this line 👇
if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
              print("Leap year")
        else:
            print("Not leap year")
    else:
        print("Leap year")
else:
    print("Not leap year")
# Out:
# 2024
# Leap year

# %% [markdown]
# ###### Multiple If Statements in Succession

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# if condition1:
#     do A
# if condition2:
#     do B
# if condition3:
#     do C

# %%
print("Welcome to the rollercoaster!")
height = int(input("What is your height in cm? "))
BILL = 0 

if height >= 120:
    print("You can ride the rollercoaster!")
    age = int(input("what is your age? "))
    if age < 12:
        bill = 5
        print("Child tickets are $5.")
    elif age <= 18: 
        bill = 7
        print("Youth tickets are $7.")
    else:
        bill = 12
        print("Adult tickets are $12.")
    
    wants_photo = input("Do you want a photo taken? Y or N. ")
    if wants_photo == "Y":
        bill += 3 # bill = bill + 3 
        
    print(f"Your final bill is ${bill}")
    
else:
    print("Sorry, you have to grow taller before you can ride.")
# Out:
# Welcome to the rollercoaster!
# What is your height in cm? 174
# You can ride the rollercoaster!
# what is your age? 45
# Adult tickets are $12.
# Do you want a photo taken? Y or N. Y
# Your final bill is $15

# %% [markdown]
# ###### Interactive Coding Exercise -  Pizza Order Practice

# %% [raw]
# Congratulations, you've got a job at Python Pizza! Your first job is to build an automatic pizza order program.
#
# Based on a user's order, work out their final bill.
#
# Small pizza (S): $15
#
# Medium pizza (M): $20
#
# Large pizza (L): $25
#
# Add pepperoni for small pizza (Y or N): +$2
#
# Add pepperoni for medium or large pizza (Y or N): +$3
#
# Add extra cheese for any size pizza (Y or N): +$1
#
# Example Input
# L
# Y
# N
# Example Output
# Thank you for choosing Python Pizza Deliveries!
# Your final bill is: $28.

# %%
print("Thank you for choosing Python Pizza Deliveries!")
size = input("What size pizza do you want? S, M, or L : ") # What size pizza do you want? S, M, or L
add_pepperoni = input("Do you want pepperoni? Y or N : ") # Do you want pepperoni? Y or N
extra_cheese = input("Do you want extra cheese? Y or N : ") # Do you want extra cheese? Y or N


# Write your code below this line 👇
bill = 0

if size == "S":
    bill += 15
elif size == "M":
    bill += 20
else:
    bill += 25
    
if add_pepperoni == "Y":
    if size == "S":
        bill += 2
    else:
        bill += 3
        
if extra_cheese == "Y":
    bill += 1
    
print(f"Your final bill is: ${bill}.")
# Out:
# Thank you for choosing Python Pizza Deliveries!
# What size pizza do you want? S, M, or L : L
# Do you want pepperoni? Y or N : Y
# Do you want extra cheese? Y or N : N
# Your final bill is: $28.

# %% [markdown]
# ### 3. Logical Opeartors

# %% [raw]
# # If we want to multiple condition of code in same line of code for that we need logical operators
#
# if cond1 & cond2 & cond3:
#     do this
# else:
#     do this

# %% [markdown]
# #### and , or, not

# %% [markdown]
# ###### and >> both conditions should be True

# %%
a = 12
a > 15
# Out:
# False

# %%
a> 10
# Out:
# True

# %%
a>10 and a<13
# Out:
# True

# %%
a>15 and a<13
# Out:
# False

# %% [markdown]
# ###### or >> any one condition should be True

# %%
a>10 or a<10
# Out:
# True

# %% [markdown]
# ###### not > The 'not' operator in Python is a logical operator that returns the inverse of the truth value of the operand it precedes. If the operand is True, 'not' will return False, and if the operand is False, 'not' will return True.

# %%
not a>15
# Out:
# True

# %%
not a<15
# Out:
# False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Welcome to the rollercoaster!")
height = int(input("What is your height in cm? "))
BILL = 0 

if height >= 120:
    print("You can ride the rollercoaster!")
    age = int(input("what is your age? "))
    if age < 12:
        bill = 5
        print("Child tickets are $5.")
    elif age <= 18: 
        bill = 7
        print("Youth tickets are $7.")
    elif age>= 45 and age <= 55:
        bill = 0
        print("Everything is going to be ok. Hvae a free ride on us!")
    else:
        bill = 12
        print("Adult tickets are $12.")
    
    wants_photo = input("Do you want a photo taken? Y or N. ")
    if wants_photo == "Y":
        bill += 3 # bill = bill + 3 
        
    print(f"Your final bill is ${bill}")
    
else:
    print("Sorry, you have to grow taller before you can ride.")
# Out:
# Welcome to the rollercoaster!
# What is your height in cm? 121
# You can ride the rollercoaster!
# what is your age? 55
# Everything is going to be ok. Hvae a free ride on us!
# Do you want a photo taken? Y or N. N
# Your final bill is $0

# %% [markdown]
# ###### Quiz

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4. Day3 Project - Treasure Island

# %%
# print source = https://ascii.co.uk/art/treasure

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/[TomekK]
*******************************************************************************
''')

print("Welcome to Treasure Island, \nYour mission is to find the treasure.")
print("You're at a cross road. where do you want to go?")

walk = input("Type \"left\" or \"right\" :  ")

if walk == "left":
    print("You've come to a lake. There is an island in the middle of the lake.")
    swim = input("Type \"wait\" to wait a boat. Type \"swim\" to swim across. : ")
    if swim == "wait":
        door = input("which door you want to open? Type \"Red\" or \"Yellow\" or \"Blue\" : ")
        if door == "Red":
            print("Burned by fire Game Over")
        elif door == "Blue":
            print("Eaten by beasts Game Over")
        elif door == "Yellow":
            print("You Win")
        else:
            print("Game Over")
    else:
        print("Attacked by trout. Game Over")
else:
    print("Fall into a hole Game Over")
# Out:
# *******************************************************************************
#           |                   |                  |                     |
#  _________|________________.=""_;=.______________|_____________________|_______
# |                   |  ,-"_,=""     `"=.|                  |
# |___________________|__"=._o`"-._        `"=.______________|___________________
#           |                `"=._o`"=._      _`"=._                     |
#  _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
# |                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
# |___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
#           |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
#  _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
# |                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
# |___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
# ...
