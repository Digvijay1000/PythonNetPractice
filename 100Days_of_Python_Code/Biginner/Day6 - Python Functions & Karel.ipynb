# %% [markdown]
# # Day6 - Python Functions & Karel

# %% [markdown]
# ## Python built in functions : https://docs.python.org/3/library/functions.html

# %% [markdown]
# ###### Defining and Calling Python Functions

# %%
print("Hello")
# Out:
# Hello

# %%
num_char = len("Hello") # Python built-in function
print(num_char)
# Out:
# 5

# %%
# how we will define own function "def" key word required

def my_function():
    print("Hello")
    print("Bye")
    
# execute the function/ call the function
my_function()
# Out:
# Hello
# Bye

# %% [raw]
# # Defining the function
#
# def my_function:
#     # Do this
#     # Then do this
#     # Finally do this
#
# # Calling the function
# my_function()

# %%
# Robot code practice

# %% [markdown]
# https://reeborg.ca/reeborg.html?lang=en&mode=python&menu=worlds%2Fmenus%2Freeborg_intro_en.js

# %% [markdown]
# ###### Indentation

# %% [raw]
# def my_function():
# ....print("Hello")
#
# print("World")

# %% [raw]
# def my_function():
# ....if sky == "clear":
# ........print("blue")
# ....elif sky == "cloudy":
# ........print("grey")
# ....print("Hello")
#
# print("World")

# %% [markdown]
# ###### spaces vs tabs

# %% [markdown]
# Spaces are the preferred indentation method.
#
# Tabs should be used solely to remain consistent with code that is already indented with tabs.
#
# Python disallows mixing tabs and spaces for indentation.

# %% [markdown]
# ###### Indentation Quiz

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def add():
  print("Hello")
add()
# Out:
# Hello

# %%
def add():
  print("Hello")
print("Bye")
add()
# Out:
# Bye
# Hello

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### While Loop
#
# Loop continuely going till condition is true

# %% [raw]
# while something_is_true:
#     # Do something repeatedly

# %%
number_of_hurdles = 6
while number_of_hurdles > 0:
    print("jump() function performed")
    number_of_hurdles -= 1
    print(number_of_hurdles)
# Out:
# jump() function performed
# 5
# jump() function performed
# 4
# jump() function performed
# 3
# jump() function performed
# 2
# jump() function performed
# 1
# jump() function performed
# 0

# %% [markdown]
# while something_is_true:
#     # Do this
#     # Then do this
#     # Then do this

# %% [raw]
# while at_goal() != True:
#     step()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### Jumping over Hurdles with Variable Heights

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Day6 Project - Escaping the Maze

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # The struggle is necessary ,the more you are struggle the more you are learning , so interprit the struggle is bad thing , its a good thing. It means that you are making progress. so keep going keep practicing.
